# %%
# %run tokenizer.py
# Out:
# this is a test. in the text.
# Index: 0, Value: this
# Index: 1, Value: is
# Index: 2, Value: a
# Index: 3, Value: test.
# Index: 4, Value: in
# Index: 5, Value: the
# Index: 6, Value: text.
#
# the words
#  {'a', 'is', 'test.', 'the', 'in', 'text.', 'this'}
# ids [0, 1, 2, 3, 4, 5, 6]
# mylist[0] this
# mylist[1] is
# mylist[2] a
# mylist[3] test.
# mylist[4] in
# mylist[5] the
# mylist[6] text.
#
#  the decoded text is
#  this is a test. in the text.
