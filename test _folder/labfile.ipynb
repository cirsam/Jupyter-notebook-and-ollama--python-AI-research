# %%
# %run numbersfunction
# Out:
# 5 is Positive
# -2 is Non-positive
# 0 is Non-positive

# %%
# !python gretingsfunction.py
# Out:
# 5 is Positive
# -2 is Non-positive
# 0 is Non-positive
# Hello, World!

# %%
# !python training.py
# Out:
# got here not test folder
# got here1
# creating 11x5 array of gloatingpoint numbers
#        cols0     cols1     cols2     cols3     cols4
# 0   0.971817  0.977577  0.261803  0.853770  0.239364
# 1   0.492145  0.884394  0.100558  0.130731  0.355956
# 2   0.253254  0.791297  0.070827  0.973673  0.181596
# 3   0.615102  0.246595  0.162347  0.798634  0.304463
# 4   0.908898  0.640292  0.002305  0.505824  0.925820
# 5   0.305254  0.797839  0.507452  0.331797  0.277197
# 6   0.767827  0.124760  0.081328  0.590915  0.176519
# 7   0.014502  0.322799  0.192250  0.180942  0.193410
# 8   0.824791  0.454470  0.152248  0.137704  0.067374
# 9   0.597086  0.398106  0.349388  0.507744  0.649586
# 10  0.347013  0.749366  0.085551  0.886469  0.378717
# got here2
# get the data from a csv which contains cities, countries, and country codes
# changing cities_countries_codes to dataFrame
# displaying cities_countries_codes_df
# Traceback (most recent call last):
# ...
