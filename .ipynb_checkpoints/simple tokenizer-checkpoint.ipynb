# %%
# %run tokenizer.py
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\source\repos\Python\tokenizer.py:14
#      11             print(f"{i},{word}")
#      13 text="this is a test."
# ---> 14 tokenixer=simpletokenizer.encode(text)
#
# AttributeError: type object 'simpletokenizer' has no attribute 'encode'
